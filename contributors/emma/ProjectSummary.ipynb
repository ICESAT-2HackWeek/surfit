# %% [markdown]
# # SURFIT
#
# Our main goal for this project was to see if we could assess surface roughness along track-length scales comparing ATL03 and ATL06 ICESat-2 data, across two regions of interest.
#
# Our motivating question(s) were:
# * Are surface roughness signals hiding in ATL03 at shorter along-track length scales compared with ATL06?
#
# Some personal goals that were shared coming into this project were:
# * To familiarize ourselves with accessing ICESat-2 data via cloud (e.g., sliderule, earthaccess, etc.).
# * Learn more about the tools we've been introduced to in the tutorials.
# * Learn how to access and subset ICESat-2 data.
# * Become more comfortable learning and sharing work in a collaborative environment - team science!
#
# ## Contributors:
# * Project lead: Ben Purinton
# * Project lead: David Clemens-Sewall
# * Project lead: Jessica Badgeley
# * Helper: Nathan Kurtz
# * Helper: YoungHyun Koo
# * Team member: Chancelor Roberts
# * Team member: Emma Robertson
# * Team member: Karina Zikan
# * Team member: 'Ana Fonongava'inga Stringer
#
# ## Table of Contents:
# Finding Regions of Interest/ Study Sites
#
# Utqiagvik:
#
# Blackrock Desert:
#
# Data Access
# ATL03
# ATL06
#
# Data Cleaning
#
# Roughness
# Use zoomed in png
#
# Evaluation against the DEM
#
# Future Steps

# %% [markdown]
# #  Study Sites
# ## Utqiagvik
# <div>
# <img src="../../data/utqiagvik_open_altimetry_sentinel_plot.png" style="maxwidth:50"/>
# </div>
#
# ## Blackrock Desert
# <div>
# <img src="../../data/blackrock_open_altimetry_sentinel_plot.png" style="maxwidth:50"/>
# </div>

# %% [markdown]
# # Data Access
# ## ATL03
# ### Jupyter Notebook: ATL03_Retrieval
# ### Author: YoungHyun Koo
# Based on SlideRule Tutorials

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Utqiagvik

# %%
df_u3 = pd.read_csv('../../data/utqiagvik_ATL03_gt1l.csv')
df_u3.head()
# Out:
#                             time  rgt  cycle  solar_elevation  sc_orient  \
# 0  2022-04-17 01:15:52.821399040  381     15        23.647131          0
# 1  2022-04-17 01:15:52.821399040  381     15        23.647131          0
# 2  2022-04-17 01:15:52.821399040  381     15        23.647131          0
# 3  2022-04-17 01:15:52.821399040  381     15        23.647131          0
# 4  2022-04-17 01:15:52.821399040  381     15        23.647131          0
#
#    background_rate  segment_id  track  segment_dist  quality_ph  ...  \
# 0     4.383076e+06      603406      1  1.208687e+07           0  ...
# 1     4.383076e+06      603406      1  1.208687e+07           0  ...
# 2     4.383076e+06      603406      1  1.208687e+07           0  ...
# 3     4.383076e+06      603406      1  1.208687e+07           0  ...
# 4     4.383076e+06      603406      1  1.208687e+07           0  ...
#
#     distance  landcover  ref_azimuth  ref_elev     geoid  pair  \
# 0 -19.083188        255    -0.429723  1.567638 -1.200101     0
# 1 -18.968743        255    -0.429723  1.567638 -1.200101     0
# 2 -18.953404        255    -0.429723  1.567638 -1.200101     0
# 3 -18.667858        255    -0.429723  1.567638 -1.200101     0
# 4 -18.646224        255    -0.429723  1.567638 -1.200101     0
#
#                                         geometry  spot      x_atc  \
# 0   POINT (-156.48801280872732 71.5639958737761)     1 -19.083188
# 1  POINT (-156.48801123405883 71.56399477338712)     1 -18.968743
# 2  POINT (-156.48801101841624 71.56399462447574)     1 -18.953404
# 3  POINT (-156.48800708980022 71.56399188036494)     1 -18.667858
# 4  POINT (-156.48800679130701 71.56399167163984)     1 -18.646224
#
#    height_ortho
# 0     47.466770
# 1      5.093244
# 2     -0.694184
# 3   -106.397990
# 4   -114.431114
#
# [5 rows x 26 columns]

# %%
# %matplotlib widget
plt.figure(figsize=[10, 3])
plt.scatter(df_u3['x_atc']/1000, df_u3.height, color='black',s=2)
plt.title("ATL03 Utqiagvik")
plt.xlabel('N-S along track distance (km)')
plt.ylabel('Elevation (m)')
# Out:
# Text(0, 0.5, 'Elevation (m)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Blackrock Desert

# %%
df_br3 = pd.read_csv('../../data/blackrock_ATL03_gt1l.csv') 
df_br3.head()
# Out:
#                             time  rgt  cycle  solar_elevation  sc_orient  \
# 0  2020-07-08 17:09:55.676380672  204      8         49.54547          0
# 1  2020-07-08 17:09:55.676380672  204      8         49.54547          0
# 2  2020-07-08 17:09:55.676380672  204      8         49.54547          0
# 3  2020-07-08 17:09:55.676380672  204      8         49.54547          0
# 4  2020-07-08 17:09:55.676380672  204      8         49.54547          0
#
#    background_rate  segment_id  track  segment_dist  quality_ph  ...  \
# 0       2243652.25      225377      1  4.519829e+06           0  ...
# 1       2243652.25      225377      1  4.519829e+06           0  ...
# 2       2243652.25      225377      1  4.519829e+06           0  ...
# 3       2243652.25      225377      1  4.519829e+06           0  ...
# 4       2243652.25      225377      1  4.519829e+06           0  ...
#
#     distance  landcover  ref_azimuth  ref_elev      geoid  pair  \
# 0 -19.900970        255     2.590355  1.568278 -22.115574     0
# 1 -19.815664        255     2.590355  1.568278 -22.115574     0
# 2 -19.769168        255     2.590355  1.568278 -22.115574     0
# 3 -19.732248        255     2.590355  1.568278 -22.115574     0
# 4 -19.730091        255     2.590355  1.568278 -22.115574     0
#
#                                          geometry  spot      x_atc  \
# 0   POINT (-119.21472117038138 40.61610069909322)     1 -19.900970
# 1   POINT (-119.21472175211399 40.61610142800616)     1 -19.815664
# 2   POINT (-119.21472207011705 40.61610182566638)     1 -19.769168
# 3   POINT (-119.21472232152944 40.61610214078288)     1 -19.732248
# 4  POINT (-119.21472233667564 40.616102159557656)     1 -19.730091
#
#    height_ortho
# 0     1498.6177
# 1     1461.3494
# 2     1440.9696
# 3     1424.8641
# 4     1423.8920
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize=[10, 3])
plt.scatter(df_br3['x_atc']/1000, df_br3.height, color='black',s=2)
plt.title("ATL03 Blackrock Desert")
plt.xlabel('N-S along track distance (km)')
plt.ylabel('Elevation (m)')
# Out:
# Text(0, 0.5, 'Elevation (m)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## ATL06
# ### Jupyter Notebook: ATL06_Retrieval
# ### Author: Chance Roberts, Emma Robertson, Jessica Badgeley
# Based on SlideRule Tutorials

# %% [markdown]
# ## Utqiagvik

# %%
df_u6 = pd.read_csv('../../data/utqiagvik_ATL06_len20_res10.csv')
df_u6.head()
# Out:
#                             time  gt  segment_id   h_sigma  n_fit_photons  \
# 0  2022-04-17 01:15:52.822686208  10      603405  5.439221            398
# 1  2022-04-17 01:15:52.824097280  10      603406  4.832015            524
# 2  2022-04-17 01:15:52.825504000  10      603406  4.613931            615
# 3  2022-04-17 01:15:52.826915328  10      603406  4.306992            652
# 4  2022-04-17 01:15:52.828324608  10      603407  4.353674            635
#
#    rgt  dh_fit_dy  pflags  cycle  spot     h_mean      distance  dh_fit_dx  \
# 0  381        0.0       4     15     1   6.711406  1.208686e+07   1.197411
# 1  381        0.0       4     15     1  13.706023  1.208687e+07  -0.323133
# 2  381        0.0       4     15     1  14.725704  1.208688e+07  -0.261386
# 3  381        0.0       4     15     1  17.030891  1.208689e+07  -0.533503
# 4  381        0.0       4     15     1  12.229053  1.208690e+07  -1.265971
#
#    w_surface_window_final  rms_misfit  \
# 0               30.540110  104.095798
# 1               14.416968  110.499813
# 2               15.036317  114.105885
# 3               20.412795  109.534093
# 4               32.288045  109.704130
#
#                                         geometry
# 0  POINT (-156.48805225057467 71.56391541437216)
# 1   POINT (-156.48808898103903 71.5638265445852)
# 2  POINT (-156.48812547398856 71.56373766462539)
# 3  POINT (-156.48816213620987 71.56364867758063)
# 4   POINT (-156.4881984978751 71.56355979232981)

# %%
plt.figure(figsize=[10, 3])
plt.plot((df_u6['distance']-np.min(df_u6['distance']))/1000, df_u6.h_mean, color='black')
plt.title("ATL06 Utqiagvik")
plt.xlabel('N-S along track distance (km)')
plt.ylabel('Elevation (m)')
# Out:
# Text(0, 0.5, 'Elevation (m)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Blackrock Desert

# %%
df_br6 = pd.read_csv('../../data/blackrock_ATL06_len20_res10.csv') 
df_br6.head()
# Out:
#                             time  gt  segment_id   h_sigma  n_fit_photons  \
# 0  2020-07-08 17:09:55.677755904  10      225376  5.864543            261
# 1  2020-07-08 17:09:55.679169536  10      225377  5.816762            270
# 2  2020-07-08 17:09:55.680584960  10      225377  5.691299            274
# 3  2020-07-08 17:09:55.682006016  10      225378  5.722453            263
# 4  2020-07-08 17:09:55.683427840  10      225378  5.894483            237
#
#    rgt  dh_fit_dy  pflags  cycle  spot       h_mean      distance  dh_fit_dx  \
# 0  204        0.0       4      8     1  1400.536424  4.519819e+06  -1.388280
# 1  204        0.0       4      8     1  1399.872841  4.519829e+06   0.802683
# 2  204        0.0       4      8     1  1400.421535  4.519839e+06  -0.052200
# 3  204        0.0       4      8     1  1397.346024  4.519849e+06   0.850886
# 4  204        0.0       4      8     1  1408.515679  4.519859e+06   1.684380
#
#    w_surface_window_final  rms_misfit  \
# 0               35.406414   94.552094
# 1               30.000000   95.566302
# 2               13.113408   94.204754
# 3               23.385282   92.802266
# 4               42.956041   89.826672
#
#                                          geometry
# 0   POINT (-119.21473370634058 40.61618935226493)
# 1    POINT (-119.2147453650196 40.61627896638442)
# 2  POINT (-119.21475706551091 40.616368577438564)
# 3    POINT (-119.21476890752193 40.6164585832068)
# 4  POINT (-119.21478053955005 40.616548199364736)

# %%
plt.figure(figsize=[10, 3])
plt.plot((df_br6['distance']-np.min(df_br6['distance']))/1000, df_br6.h_mean, color='black')
plt.title("ATL06 Blackrock Desert")
plt.xlabel('N-S along track distance (km)')
plt.ylabel('Elevation (m)')
# Out:
# Text(0, 0.5, 'Elevation (m)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Roughness

# %% [markdown]
# # DEM Evaluation

# %% [markdown]
# # Future Steps
